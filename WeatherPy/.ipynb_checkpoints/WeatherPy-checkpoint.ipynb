# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import scipy.stats as st
import json
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key = weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

response = requests.get(query_url + city).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1612742722,
#  'id': 5106841,
#  'main': {'feels_like': 20.28,
#           'humidity': 62,
#           'pressure': 1010,
#           'temp': 27.32,
#           'temp_max': 28,
#           'temp_min': 26.01},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1612699381,
#          'sunset': 1612736226,
#          'type': 3},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 302, 'gust': 5.99, 'speed': 3}}

# %%
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
city_name = []
country = []
date = []

sets = 1
counter = 1

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        temperature.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_record = response["name"]
        print(f"Processing Record {counter} of Set {sets} | {city_record}")
        
        counter += 1
        
        if counter == 51:
            counter = 0 
            sets += 1
                    
    except:
        print("City not found. Skipping...") 
    continue
    
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Mehamn
# Processing Record 2 of Set 1 | Jalu
# Processing Record 3 of Set 1 | Udachny
# Processing Record 4 of Set 1 | Hilo
# Processing Record 5 of Set 1 | Hong Kong
# Processing Record 6 of Set 1 | Celendín
# Processing Record 7 of Set 1 | Arraial do Cabo
# Processing Record 8 of Set 1 | Mahébourg
# Processing Record 9 of Set 1 | Linares
# Processing Record 10 of Set 1 | Juli
# Processing Record 11 of Set 1 | Hithadhoo
# Processing Record 12 of Set 1 | Albany
# Processing Record 13 of Set 1 | Busselton
# Processing Record 14 of Set 1 | Avarua
# Processing Record 15 of Set 1 | Port Lincoln
# Processing Record 16 of Set 1 | Punta Arenas
# Processing Record 17 of Set 1 | Toamasina
# Processing Record 18 of Set 1 | Zhangaözen
# Processing Record 19 of Set 1 | Rozivka
# Processing Record 20 of Set 1 | Upernavik
# Processing Record 21 of Set 1 | Viedma
# Processing Record 22 of Set 1 | Ponta do Sol
# Processing Record 23 of Set 1 | Tërny
# Processing Record 24 of Set 1 | Muli
# Processing Record 25 of Set 1 | Tazovsky
# Processing Record 26 of Set 1 | Mataura
# Processing Record 27 of Set 1 | Bambous Virieux
# Processing Record 28 of Set 1 | Cape Town
# Processing Record 29 of Set 1 | Hermanus
# Processing Record 30 of Set 1 | Avera
# Processing Record 31 of Set 1 | Matagami
# Processing Record 32 of Set 1 | San Rafael
# Processing Record 33 of Set 1 | Airai
# Processing Record 34 of Set 1 | Rikitea
# Processing Record 35 of Set 1 | Vardø
# City not found. Skipping...
# Processing Record 36 of Set 1 | Port Alfred
# Processing Record 37 of Set 1 | Hay River
# Processing Record 38 of Set 1 | Kapaa
# Processing Record 39 of Set 1 | Deputatsky
# Processing Record 40 of Set 1 | Jamestown
# Processing Record 28 of Set 4 | Chapais
# Processing Record 29 of Set 4 | Imeni Poliny Osipenko
# Processing Record 30 of Set 4 | Coquimbo
# Processing Record 31 of Set 4 | Havre-St-Pierre
# Processing Record 32 of Set 4 | Slave Lake
# Processing Record 33 of Set 4 | Wau
# Processing Record 34 of Set 4 | Sørland
# Processing Record 35 of Set 4 | Sibu
# Processing Record 36 of Set 4 | Port Hardy
# Processing Record 37 of Set 4 | Lao Cai
# City not found. Skipping...
# Processing Record 38 of Set 4 | Koslan
# City not found. Skipping...
# Processing Record 39 of Set 4 | Tālbahat
# Processing Record 40 of Set 4 | Cabedelo
# Processing Record 41 of Set 4 | Lata
# Processing Record 42 of Set 4 | Bonavista
# Processing Record 43 of Set 4 | Souillac
# Processing Record 44 of Set 4 | Yangi Marg`ilon
# Processing Record 45 of Set 4 | Vila Velha
# Processing Record 46 of Set 4 | Khovu-Aksy
# Processing Record 47 of Set 4 | Rangia
# Processing Record 48 of Set 4 | Labuhan
# Processing Record 49 of Set 4 | Suntar
# Processing Record 50 of Set 4 | Finschhafen
# Processing Record 0 of Set 5 | Vitré
# Processing Record 1 of Set 5 | Necochea
# Processing Record 2 of Set 5 | Raymond
# Processing Record 3 of Set 5 | Te Anau
# Processing Record 4 of Set 5 | Hasaki
# Processing Record 5 of Set 5 | Iqaluit
# Processing Record 6 of Set 5 | Akçakoca
# Processing Record 7 of Set 5 | Ilulissat
# Processing Record 8 of Set 5 | Healdsburg
# Processing Record 9 of Set 5 | Codrington
# Processing Record 10 of Set 5 | Mbigou
# Processing Record 11 of Set 5 | Cabo San Lucas
# Processing Record 12 of Set 5 | Mlowo
# City not found. Skipping...
# Processing Record 13 of Set 5 | Mountain Home
# Processing Record 14 of Set 5 | Paysandu
# Processing Record 15 of Set 5 | Sirsi
# Processing Record 16 of Set 5 | Severo-Kuril'sk
# Processing Record 17 of Set 5 | Rognan
# Processing Record 18 of Set 5 | Cherskiy
# Processing Record 19 of Set 5 | Lumberton
# Processing Record 20 of Set 5 | Praia da Vitória
# Processing Record 21 of Set 5 | Novikovo
# Processing Record 22 of Set 5 | Sorsk
# Processing Record 23 of Set 5 | Puteyets
# Processing Record 24 of Set 5 | Hīt
# Processing Record 25 of Set 5 | Vaitape
# Processing Record 26 of Set 5 | Shache
# Processing Record 27 of Set 5 | Tahoua
# Processing Record 28 of Set 5 | Tual
# Processing Record 29 of Set 5 | Santa Barbara
# Processing Record 30 of Set 5 | Māngrol
# Processing Record 31 of Set 5 | Plettenberg Bay
# Processing Record 32 of Set 5 | Lompoc
# Processing Record 33 of Set 5 | Sydney
# Processing Record 34 of Set 5 | Tuy Hoa
# Processing Record 35 of Set 5 | Talnakh
# Processing Record 36 of Set 5 | Denpasar
# Processing Record 37 of Set 5 | Coron
# Processing Record 38 of Set 5 | Hervey Bay
# Processing Record 39 of Set 5 | Manggar
# Processing Record 40 of Set 5 | Lüderitz
# Processing Record 41 of Set 5 | Guerrero Negro
# Processing Record 42 of Set 5 | Aksarka
# City not found. Skipping...
# Processing Record 43 of Set 5 | Narsaq
# Processing Record 44 of Set 5 | Port Augusta
# Processing Record 45 of Set 5 | Nanpiao
# City not found. Skipping...
# Processing Record 46 of Set 5 | Celestún
# City not found. Skipping...
# Processing Record 47 of Set 5 | Ferrol
# City not found. Skipping...
# Processing Record 48 of Set 5 | Calabozo
# Processing Record 49 of Set 5 | Tari
# Processing Record 50 of Set 5 | Leshukonskoye
# Processing Record 0 of Set 6 | Kaitangata
# Processing Record 1 of Set 6 | Tbilisskaya
# Processing Record 2 of Set 6 | Loíza
# Processing Record 3 of Set 6 | Agüimes
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 6 | Egvekinot
# Processing Record 5 of Set 6 | Grand Gaube
# Processing Record 6 of Set 6 | Portland
# Processing Record 7 of Set 6 | Los Llanos de Aridane
# Processing Record 8 of Set 6 | Manta
# Processing Record 9 of Set 6 | Auki
# Processing Record 10 of Set 6 | Salalah
# Processing Record 11 of Set 6 | Kichera
# Processing Record 12 of Set 6 | Jiaozuo
# Processing Record 13 of Set 6 | São Gabriel da Cachoeira
# Processing Record 14 of Set 6 | Niamey
# Processing Record 15 of Set 6 | Valparaíso
# Processing Record 16 of Set 6 | Morehead
# Processing Record 17 of Set 6 | Saint-François
# Processing Record 18 of Set 6 | Aksu
# Processing Record 19 of Set 6 | Itarema
# Processing Record 20 of Set 6 | Novochernorechenskiy
# Processing Record 21 of Set 6 | Yar-Sale
# Processing Record 22 of Set 6 | Vuktyl
# City not found. Skipping...
# Processing Record 23 of Set 6 | Mugur-Aksy
# Processing Record 24 of Set 6 | Haicheng
# Processing Record 25 of Set 6 | Genhe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 6 | Clyde River
# Processing Record 27 of Set 6 | San Andrés
# Processing Record 28 of Set 6 | San Patricio
# Processing Record 29 of Set 6 | Kelso
# Processing Record 30 of Set 6 | Kungurtug
# Processing Record 31 of Set 6 | Darhan
# Processing Record 32 of Set 6 | Fortuna
# Processing Record 33 of Set 6 | Nouadhibou
# Processing Record 34 of Set 6 | Beringovskiy
# Processing Record 35 of Set 6 | Roald
# Processing Record 36 of Set 6 | Comodoro Rivadavia
# Processing Record 37 of Set 6 | Poum
# City not found. Skipping...
# Processing Record 38 of Set 6 | Butterworth
# Processing Record 39 of Set 6 | Qūchān
# Processing Record 40 of Set 6 | Chara
# Processing Record 41 of Set 6 | Suining
# Processing Record 42 of Set 6 | Tuatapere
# Processing Record 43 of Set 6 | Opuwo
# Processing Record 44 of Set 6 | Mana
# Processing Record 45 of Set 6 | Atar
# Processing Record 46 of Set 6 | Bonito
# Processing Record 47 of Set 6 | The Valley
# Processing Record 48 of Set 6 | Trairi
# Processing Record 49 of Set 6 | Nome
# Processing Record 50 of Set 6 | Riyadh
# Processing Record 0 of Set 7 | Angoche
# Processing Record 1 of Set 7 | Luena
# Processing Record 2 of Set 7 | Dingle
# Processing Record 3 of Set 7 | Oldsmar
# Processing Record 4 of Set 7 | Rey Bouba
# Processing Record 5 of Set 7 | Fairbanks
# Processing Record 6 of Set 7 | Auckland
# Processing Record 7 of Set 7 | Kattivākkam
# City not found. Skipping...
# Processing Record 8 of Set 7 | San Cristobal
# Processing Record 9 of Set 7 | Lengshuitan
# Processing Record 10 of Set 7 | Siocon
# Processing Record 11 of Set 7 | Arrondissement de Saint-Denis
# Processing Record 47 of Set 9 | Belaya Gora
# Processing Record 48 of Set 9 | Byron Bay
# Processing Record 49 of Set 9 | Lazarev
# Processing Record 50 of Set 9 | Aloleng
# Processing Record 0 of Set 10 | Vestmannaeyjar
# Processing Record 1 of Set 10 | Manaquiri
# Processing Record 2 of Set 10 | Paranaíba
# Processing Record 3 of Set 10 | Waipawa
# Processing Record 4 of Set 10 | Coolum Beach
# Processing Record 5 of Set 10 | Katobu
# Processing Record 6 of Set 10 | Olden
# Processing Record 7 of Set 10 | Nantucket
# Processing Record 8 of Set 10 | Skjervøy
# Processing Record 9 of Set 10 | Lavrentiya
# Processing Record 10 of Set 10 | Lewisporte
# Processing Record 11 of Set 10 | Pitimbu
# Processing Record 12 of Set 10 | Kefamenanu
# Processing Record 13 of Set 10 | Maxixe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 10 | Baní
# Processing Record 15 of Set 10 | Swan Hill
# Processing Record 16 of Set 10 | Champerico
# Processing Record 17 of Set 10 | Khandyga
# Processing Record 18 of Set 10 | Ballybofey
# Processing Record 19 of Set 10 | Claremore
# Processing Record 20 of Set 10 | Kulhudhuffushi
# Processing Record 21 of Set 10 | Puerto Madero
# Processing Record 22 of Set 10 | Jacobina
# Processing Record 23 of Set 10 | Morón
# Processing Record 24 of Set 10 | Dali
# Processing Record 25 of Set 10 | Kainantu
# Processing Record 26 of Set 10 | El Reno
# Processing Record 27 of Set 10 | Port Moresby
# Processing Record 28 of Set 10 | Abhā
# Processing Record 29 of Set 10 | Fuyu
# Processing Record 30 of Set 10 | Dekar
# Processing Record 31 of Set 10 | Jenbach
# Processing Record 32 of Set 10 | Oranjemund
# Processing Record 33 of Set 10 | Haines Junction
# Processing Record 34 of Set 10 | Beidao
# Processing Record 35 of Set 10 | La Asuncion
# Processing Record 36 of Set 10 | Ekenäs
# Processing Record 37 of Set 10 | Fengcheng
# Processing Record 38 of Set 10 | Kokopo
# City not found. Skipping...
# Processing Record 39 of Set 10 | Teplodar
# City not found. Skipping...
# Processing Record 40 of Set 10 | Fonte Boa
# Processing Record 41 of Set 10 | Samarkand
# Processing Record 42 of Set 10 | Tornio
# Processing Record 43 of Set 10 | Lewistown
# Processing Record 44 of Set 10 | Isabela
# Processing Record 45 of Set 10 | Rome
# Processing Record 46 of Set 10 | Lakselv
# Processing Record 47 of Set 10 | Cabinda
# Processing Record 48 of Set 10 | Katsuura
# Processing Record 49 of Set 10 | Tangshan
# Processing Record 50 of Set 10 | Port Hedland
# Processing Record 0 of Set 11 | Villazón
# Processing Record 1 of Set 11 | Yumen
# Processing Record 2 of Set 11 | Sakakah
# Processing Record 3 of Set 11 | Buala
# Processing Record 4 of Set 11 | Collie
# Processing Record 5 of Set 11 | Belmonte
# Processing Record 6 of Set 11 | Dabat
# Processing Record 7 of Set 11 | Santa Maria
# City not found. Skipping...
# Processing Record 8 of Set 11 | Maţāy
# Processing Record 9 of Set 11 | Newport
# Processing Record 10 of Set 11 | Huilong
# Processing Record 11 of Set 11 | Bichura
# Processing Record 12 of Set 11 | Oskarshamn
# Processing Record 13 of Set 11 | Omsukchan
# Processing Record 14 of Set 11 | Pisco
# Processing Record 15 of Set 11 | Sioux Lookout
# City not found. Skipping...
# Processing Record 16 of Set 11 | Vila Franca do Campo
# Processing Record 17 of Set 11 | Walvis Bay
# Processing Record 18 of Set 11 | Ajdabiya
# Processing Record 19 of Set 11 | Benguela
# Processing Record 20 of Set 11 | Cap-aux-Meules
# Processing Record 21 of Set 11 | Dunedin
# Processing Record 22 of Set 11 | Tarakan
# Processing Record 23 of Set 11 | Ryōtsu-minato
# Processing Record 24 of Set 11 | Joinville
# Processing Record 25 of Set 11 | Russell
# Processing Record 26 of Set 11 | ‘Ewa Beach
# Processing Record 27 of Set 11 | Alice Springs
# Processing Record 28 of Set 11 | Rodrigues Alves
# Processing Record 29 of Set 11 | Tortolì
# Processing Record 30 of Set 11 | Shalinskoye
# Processing Record 31 of Set 11 | Esperance
# Processing Record 32 of Set 11 | Storslett
# Processing Record 33 of Set 11 | Fukuechō
# Processing Record 34 of Set 11 | Nīlēshwar
# Processing Record 35 of Set 11 | Orsha
# Processing Record 36 of Set 11 | Harper
# Processing Record 37 of Set 11 | Uyuni
# Processing Record 38 of Set 11 | Port-Gentil
# Processing Record 39 of Set 11 | Prieska
# Processing Record 40 of Set 11 | Al Bardīyah
# Processing Record 41 of Set 11 | São João da Barra
# Processing Record 42 of Set 11 | Kavaratti
# Processing Record 43 of Set 11 | El Carmen
# Processing Record 44 of Set 11 | Strai
# Processing Record 45 of Set 11 | Mangrūl Pīr
# Processing Record 46 of Set 11 | Knysna
# Processing Record 47 of Set 11 | Olafsvik
# Processing Record 48 of Set 11 | Mattru
# Processing Record 49 of Set 11 | Doka
# Processing Record 50 of Set 11 | Tuluá
# Processing Record 0 of Set 12 | Dakar
# Processing Record 1 of Set 12 | Guangyuan
# Processing Record 2 of Set 12 | Maceió
# Processing Record 3 of Set 12 | La Santisima Trinidad
# Processing Record 4 of Set 12 | Zyryanka
# Processing Record 5 of Set 12 | Mazurivka
# Processing Record 6 of Set 12 | Flin Flon
# Processing Record 7 of Set 12 | Hofn
# Processing Record 8 of Set 12 | Sukhobuzimskoye
# Processing Record 9 of Set 12 | Salekhard
# Processing Record 10 of Set 12 | La Grande
# Processing Record 11 of Set 12 | Pangai
# Processing Record 12 of Set 12 | Vostok
# Processing Record 13 of Set 12 | Fare
# Processing Record 14 of Set 12 | Lucea
# Processing Record 15 of Set 12 | Makīnsk
# Processing Record 16 of Set 12 | Mwinilunga
# Processing Record 17 of Set 12 | Nishihara
# Processing Record 18 of Set 12 | Solnechnyy
# Processing Record 19 of Set 12 | Hemnesberget
# Processing Record 20 of Set 12 | Buraidah
# Processing Record 21 of Set 12 | High Level
# Processing Record 22 of Set 12 | Gayéri
# Processing Record 23 of Set 12 | Havøysund
# Processing Record 24 of Set 12 | Nelson Bay
# Processing Record 25 of Set 12 | Shimoda
# Processing Record 26 of Set 12 | Leningradskiy
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Lat": latitude, "Lng": longitude, "Temp": temperature, 
                           "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": wind_speed, 
                           "Country": country, "Date": date})
weather_df.head()
# Out:
#         City      Lat       Lng   Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mehamn  71.0357   27.8492  23.23        92         100       20.89
# 1       Jalu  29.0331   21.5482  67.28        25          99       18.54
# 2    Udachny  66.4167  112.4000 -27.47        83          92        5.55
# 3       Hilo  19.7297 -155.0900  76.57        47          20       14.97
# 4  Hong Kong  22.2855  114.1577  65.80        83           0        1.99
#
#   Country        Date
# 0      NO  1612742794
# 1      LY  1612743022
# 2      RU  1612743022
# 3      US  1612742384
# 4      HK  1612742885

# %%
weather_df.to_csv("./Resources/weather_df.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.loc[weather_df['Humidity'] > 100] # There is not.
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
now = datetime.date.today()
month = now.month
day = now.day 
year = now.year


plt.figure()

plt.title(f"City Latitude vs. Temperature ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(latitude, temperature, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure()

plt.title(f"City Latitude vs. Humidity ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(latitude, humidity, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure()

plt.title(f"City Latitude vs. Cloudiness ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(latitude, cloudiness, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure()

plt.title(f"City Latitude vs. Wind Speed ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(latitude, wind_speed, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Separate Northern and Southern Hemispheres
Northern = weather_df.loc[weather_df['Lat'] >= 0]
Southern = weather_df.loc[weather_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Temp vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(Northern['Temp'], Northern['Lat'])

correlation = st.pearsonr(Northern['Temp'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Temp'], Northern['Lat'])
regress_values = Northern['Temp'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Temp'],regress_values,"r-")
plt.annotate(line_eq,(-30,5),fontsize=15,color="red")

plt.savefig("./Plots/Temp_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is -0.86

# %% [markdown]
# ####  Southern Hemisphere - Temp vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(Southern['Temp'], Southern['Lat'])

correlation = st.pearsonr(Southern['Temp'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Temp'], Southern['Lat'])
regress_values = Southern['Temp'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Temp'],regress_values,"r-")
plt.annotate(line_eq,(70,-53),fontsize=15,color="red")

plt.savefig("./Plots/Temp_vs_Latitude_LRSouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.54

# %% [markdown]
# <blockquote>The analysis shows a strong negative correlation between temperature and latitude in the northern hemisphere and a Mild one in the southern hemisphere. This may sugest that in the northern hemisphere the temperatures are linked to the latitude but then again, correlation does not imply causation.</blockquote>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(Northern['Humidity'], Northern['Lat'])

correlation = st.pearsonr(Northern['Humidity'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Humidity'], Northern['Lat'])
regress_values = Northern['Humidity'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Humidity'],regress_values,"r-")
plt.annotate(line_eq,(7,71),fontsize=15,color="red")

plt.savefig("./Plots/Humidity_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.33

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(Southern['Humidity'], Southern['Lat'])

correlation = st.pearsonr(Southern['Humidity'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Humidity'], Southern['Lat'])
regress_values = Southern['Humidity'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Humidity'],regress_values,"r-")
plt.annotate(line_eq,(20,-5),fontsize=15,color="red")

plt.savefig("./Plots/Humidity_vs_Latitude_LR_SouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.4

# %% [markdown]
# <blockquote>The analysis shows a weak correlation between humidity and latitude in both northern and southern hemispheres. It may be that they are not related. </blockquote>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(Northern['Cloudiness'], Northern['Lat'])

correlation = st.pearsonr(Northern['Cloudiness'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Cloudiness'], Northern['Lat'])
regress_values = Northern['Cloudiness'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Cloudiness'],regress_values,"r-")
plt.annotate(line_eq,(20,75),fontsize=15,color="red")

plt.savefig("./Plots/Cloudiness_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.15

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(Southern['Cloudiness'], Southern['Lat'])

correlation = st.pearsonr(Southern['Cloudiness'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Cloudiness'], Southern['Lat'])
regress_values = Southern['Cloudiness'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Cloudiness'],regress_values,"r-")
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")

plt.savefig("./Plots/Cloudiness_vs_Latitude_LR_SouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.14

# %% [markdown]
# <blockquote>The analysis shows a weak correlation between cloudiness and latitude in both northern and southern hemispheres. It may be that they are not related. </blockquote>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(Northern['Wind Speed'], Northern['Lat'])

correlation = st.pearsonr(Northern['Wind Speed'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Wind Speed'], Northern['Lat'])
regress_values = Northern['Wind Speed'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Wind Speed'],regress_values,"r-")
plt.annotate(line_eq,(25,20),fontsize=15,color="red")

plt.savefig("./Plots/WindSpeed_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.16

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(Southern['Wind Speed'], Southern['Lat'])

correlation = st.pearsonr(Southern['Wind Speed'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Wind Speed'], Southern['Lat'])
regress_values = Southern['Wind Speed'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Wind Speed'],regress_values,"r-")
plt.annotate(line_eq,(15,-54),fontsize=15,color="red")

plt.savefig("./Plots/WindSpeed_vs_Latitude_LR_SouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is -0.2

# %% [markdown]
# <blockquote>The analysis shows a weak correlation between wind speed and latitude in both northern and southern hemispheres. It may be that they are not related. </blockquote>
