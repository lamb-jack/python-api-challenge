# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import scipy.stats as st
import json
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key = weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

response = requests.get(query_url + city).json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 39.8885, 'lon': 4.2658},
#  'dt': 1612807162,
#  'id': 2514301,
#  'main': {'feels_like': 50.18,
#           'humidity': 88,
#           'pressure': 1000,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Mahon',
#  'sys': {'country': 'ES',
#          'id': 6422,
#          'sunrise': 1612766645,
#          'sunset': 1612804215,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 10.36}}

# %%
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
city_name = []
country = []
date = []

sets = 1
counter = 1

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        temperature.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_record = response["name"]
        print(f"Processing Record {counter} of Set {sets} | {city_record}")
        
        counter += 1
        
        if counter == 51:
            counter = 0 
            sets += 1
                    
    except:
        print("City not found. Skipping...") 
    continue
    
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Albany
# Processing Record 2 of Set 1 | Erenhot
# Processing Record 3 of Set 1 | Kavaratti
# Processing Record 4 of Set 1 | Broken Hill
# Processing Record 5 of Set 1 | Sisimiut
# Processing Record 6 of Set 1 | Avarua
# Processing Record 7 of Set 1 | Atasū
# Processing Record 8 of Set 1 | Geraldton
# Processing Record 9 of Set 1 | Vaini
# Processing Record 10 of Set 1 | Lázaro Cárdenas
# Processing Record 11 of Set 1 | Esperance
# Processing Record 12 of Set 1 | Cockburn Town
# Processing Record 13 of Set 1 | New Norfolk
# Processing Record 14 of Set 1 | San Miguel de Cozumel
# Processing Record 15 of Set 1 | Abhā
# Processing Record 16 of Set 1 | Amasya
# Processing Record 17 of Set 1 | Dikson
# Processing Record 18 of Set 1 | Pevek
# Processing Record 19 of Set 1 | Sambava
# Processing Record 20 of Set 1 | Bluff
# Processing Record 21 of Set 1 | Kieta
# Processing Record 22 of Set 1 | Butaritari
# Processing Record 23 of Set 1 | Barrow
# Processing Record 24 of Set 1 | Glamoč
# Processing Record 25 of Set 1 | Punta Arenas
# Processing Record 26 of Set 1 | Río Gallegos
# City not found. Skipping...
# Processing Record 27 of Set 1 | Yellowknife
# Processing Record 28 of Set 1 | Binzhou
# Processing Record 29 of Set 1 | Samarai
# Processing Record 30 of Set 1 | Hilo
# Processing Record 31 of Set 1 | Tall Kayf
# Processing Record 32 of Set 1 | Tuktoyaktuk
# Processing Record 33 of Set 1 | Upernavik
# Processing Record 34 of Set 1 | Puerto Ayora
# Processing Record 35 of Set 1 | Kumul
# City not found. Skipping...
# Processing Record 36 of Set 1 | Hithadhoo
# Processing Record 37 of Set 1 | Honningsvåg
# Processing Record 38 of Set 1 | Ballina
# Processing Record 16 of Set 4 | Socorro
# Processing Record 17 of Set 4 | Kangaatsiaq
# Processing Record 18 of Set 4 | Paamiut
# Processing Record 19 of Set 4 | ‘Āhuimanu
# Processing Record 20 of Set 4 | Rabo de Peixe
# Processing Record 21 of Set 4 | Mahon
# Processing Record 22 of Set 4 | Atuona
# Processing Record 23 of Set 4 | Khilchipur
# Processing Record 24 of Set 4 | Ribeira Brava
# Processing Record 25 of Set 4 | Pyinmana
# Processing Record 26 of Set 4 | Ribeira Grande
# Processing Record 27 of Set 4 | Namatanai
# Processing Record 28 of Set 4 | Nador
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 4 | Turka
# Processing Record 30 of Set 4 | Khatanga
# Processing Record 31 of Set 4 | Eureka
# Processing Record 32 of Set 4 | Norman Wells
# Processing Record 33 of Set 4 | Richards Bay
# Processing Record 34 of Set 4 | Avera
# Processing Record 35 of Set 4 | Thompson
# Processing Record 36 of Set 4 | Tekirdağ
# Processing Record 37 of Set 4 | Dawson Creek
# Processing Record 38 of Set 4 | Neuquén
# Processing Record 39 of Set 4 | George Town
# Processing Record 40 of Set 4 | Esso
# Processing Record 41 of Set 4 | Torbay
# Processing Record 42 of Set 4 | Pemba
# Processing Record 43 of Set 4 | Kathu
# Processing Record 44 of Set 4 | Fray Bentos
# Processing Record 45 of Set 4 | Zelenets
# Processing Record 46 of Set 4 | Sandakan
# Processing Record 47 of Set 4 | Poso
# Processing Record 48 of Set 4 | San Patricio
# Processing Record 49 of Set 4 | Qui Nhon
# Processing Record 50 of Set 4 | Rockland
# Processing Record 0 of Set 5 | Puerto del Rosario
# City not found. Skipping...
# Processing Record 1 of Set 5 | Whitehorse
# Processing Record 2 of Set 5 | Chennai
# Processing Record 3 of Set 5 | Auki
# Processing Record 4 of Set 5 | Port Pirie
# Processing Record 5 of Set 5 | Provideniya
# Processing Record 6 of Set 5 | Yako
# Processing Record 7 of Set 5 | Muzhi
# Processing Record 8 of Set 5 | Saint George
# Processing Record 9 of Set 5 | Anadyr
# Processing Record 10 of Set 5 | Bone
# Processing Record 11 of Set 5 | Coquimbo
# Processing Record 12 of Set 5 | Tautira
# Processing Record 13 of Set 5 | Bambous Virieux
# City not found. Skipping...
# Processing Record 14 of Set 5 | Oranjestad
# Processing Record 15 of Set 5 | Gonzalez
# Processing Record 16 of Set 5 | Pandan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 5 | Kavieng
# Processing Record 18 of Set 5 | Sitka
# Processing Record 19 of Set 5 | Lavumisa
# Processing Record 20 of Set 5 | Vasai
# Processing Record 21 of Set 5 | Kon Tum
# Processing Record 22 of Set 5 | Okato
# Processing Record 23 of Set 5 | Tasiilaq
# City not found. Skipping...
# Processing Record 24 of Set 5 | Mossamedes
# Processing Record 25 of Set 5 | Mahébourg
# Processing Record 26 of Set 5 | Preobrazheniye
# Processing Record 27 of Set 5 | Oranjemund
# Processing Record 28 of Set 5 | Ust'-Barguzin
# Processing Record 29 of Set 5 | Manama
# Processing Record 30 of Set 5 | Ankazobe
# Processing Record 31 of Set 5 | Koksovyy
# Processing Record 32 of Set 5 | Zhoucheng
# Processing Record 33 of Set 5 | Iqaluit
# Processing Record 34 of Set 5 | Port Blair
# Processing Record 35 of Set 5 | Katsuura
# Processing Record 36 of Set 5 | Alofi
# Processing Record 37 of Set 5 | Chui
# Processing Record 38 of Set 5 | Lebu
# Processing Record 39 of Set 5 | Price
# Processing Record 40 of Set 5 | San Carlos
# City not found. Skipping...
# Processing Record 41 of Set 5 | Leningradskiy
# Processing Record 42 of Set 5 | Vao
# Processing Record 43 of Set 5 | Nampula
# Processing Record 44 of Set 5 | Necochea
# City not found. Skipping...
# Processing Record 45 of Set 5 | Marrakesh
# Processing Record 46 of Set 5 | Esmeraldas
# Processing Record 47 of Set 5 | Rocha
# Processing Record 48 of Set 5 | Vidim
# Processing Record 49 of Set 5 | Dezhou
# Processing Record 50 of Set 5 | Coyhaique
# Processing Record 0 of Set 6 | Abong Mbang
# Processing Record 1 of Set 6 | Diré
# Processing Record 2 of Set 6 | Mount Isa
# Processing Record 3 of Set 6 | Hobyo
# Processing Record 4 of Set 6 | ‘Ewa Beach
# Processing Record 5 of Set 6 | Knysna
# Processing Record 6 of Set 6 | Amapá
# Processing Record 7 of Set 6 | Dustlik
# Processing Record 8 of Set 6 | Port Lincoln
# Processing Record 9 of Set 6 | Baishishan
# Processing Record 10 of Set 6 | Aulla
# Processing Record 11 of Set 6 | Palembang
# Processing Record 12 of Set 6 | Qaanaaq
# Processing Record 13 of Set 6 | Husavik
# Processing Record 14 of Set 6 | Ust-Kuyga
# Processing Record 15 of Set 6 | Cabo San Lucas
# Processing Record 16 of Set 6 | Black River
# Processing Record 17 of Set 6 | Severo-Kuril'sk
# Processing Record 18 of Set 6 | Tilichiki
# City not found. Skipping...
# Processing Record 19 of Set 6 | Lata
# City not found. Skipping...
# Processing Record 20 of Set 6 | Ozuluama de Mascareñas
# Processing Record 21 of Set 6 | Bethel
# Processing Record 22 of Set 6 | Erzin
# Processing Record 23 of Set 6 | Tuatapere
# City not found. Skipping...
# Processing Record 24 of Set 6 | Xai-Xai
# Processing Record 25 of Set 6 | Baharly
# Processing Record 26 of Set 6 | Kotra
# City not found. Skipping...
# Processing Record 27 of Set 6 | Yerbogachën
# Processing Record 28 of Set 6 | Maniitsoq
# Processing Record 29 of Set 6 | Mount Gambier
# City not found. Skipping...
# Processing Record 30 of Set 6 | Calama
# Processing Record 31 of Set 6 | Kozhva
# Processing Record 32 of Set 6 | Yazman
# Processing Record 33 of Set 6 | Ilulissat
# Processing Record 34 of Set 6 | Caraga
# Processing Record 35 of Set 6 | Bandarbeyla
# Processing Record 36 of Set 6 | Tazovsky
# Processing Record 37 of Set 6 | Wellington
# Processing Record 38 of Set 6 | Øksfjord
# Processing Record 39 of Set 6 | San Andrés
# City not found. Skipping...
# Processing Record 40 of Set 6 | Terrace Bay
# Processing Record 41 of Set 6 | Gizo Government Station
# City not found. Skipping...
# Processing Record 42 of Set 6 | Marsabit
# Processing Record 43 of Set 6 | Kalanchak
# Processing Record 44 of Set 6 | Acaraú
# Processing Record 45 of Set 6 | Hays
# Processing Record 46 of Set 6 | Kawalu
# Processing Record 47 of Set 6 | Faya
# Processing Record 48 of Set 6 | Viking
# Processing Record 49 of Set 6 | Saskylakh
# Processing Record 50 of Set 6 | Tiarei
# Processing Record 0 of Set 7 | Kovdor
# Processing Record 1 of Set 7 | Neyshabur
# Processing Record 2 of Set 7 | Scarborough
# Processing Record 3 of Set 7 | Mergen
# Processing Record 4 of Set 7 | Atlantic City
# Processing Record 5 of Set 7 | Inhambane
# City not found. Skipping...
# Processing Record 6 of Set 7 | Wagar
# Processing Record 7 of Set 7 | Jianning
# Processing Record 8 of Set 7 | Imbituba
# Processing Record 9 of Set 7 | Pemberton
# Processing Record 10 of Set 7 | Peno
# Processing Record 11 of Set 7 | Markova
# Processing Record 12 of Set 7 | Bezhetsk
# Processing Record 13 of Set 7 | Dobele
# City not found. Skipping...
# Processing Record 14 of Set 7 | Evansville
# Processing Record 15 of Set 7 | Port Hardy
# Processing Record 16 of Set 7 | Half Moon Bay
# Processing Record 17 of Set 7 | Iquitos
# Processing Record 18 of Set 7 | Porto-Vecchio
# Processing Record 19 of Set 7 | Bereda
# Processing Record 20 of Set 7 | Winnemucca
# Processing Record 21 of Set 7 | Ulaangom
# Processing Record 22 of Set 7 | Krasnovishersk
# Processing Record 23 of Set 7 | Ngunguru
# Processing Record 24 of Set 7 | Kuytun
# Processing Record 25 of Set 7 | Puerto Baquerizo Moreno
# Processing Record 26 of Set 7 | Lake Shasta
# Processing Record 27 of Set 7 | Pekan
# Processing Record 28 of Set 7 | Noumea
# City not found. Skipping...
# Processing Record 29 of Set 7 | Kingman
# City not found. Skipping...
# Processing Record 30 of Set 7 | Pāveh
# City not found. Skipping...
# Processing Record 31 of Set 7 | Alekseyevsk
# Processing Record 32 of Set 7 | Ancud
# Processing Record 33 of Set 7 | Peniche
# Processing Record 34 of Set 7 | Kaihua
# Processing Record 35 of Set 7 | Sangāreddi
# Processing Record 36 of Set 7 | Sarangani
# Processing Record 37 of Set 7 | Gigmoto
# Processing Record 38 of Set 7 | East London
# Processing Record 39 of Set 7 | Meulaboh
# Processing Record 40 of Set 7 | Amoy
# Processing Record 41 of Set 7 | Bubaque
# Processing Record 42 of Set 7 | Zhangjiakou Shi Xuanhua Qu
# City not found. Skipping...
# Processing Record 43 of Set 7 | Wanlaweyn
# Processing Record 44 of Set 7 | Zhangaözen
# Processing Record 45 of Set 7 | Curup
# Processing Record 46 of Set 7 | Changde
# Processing Record 47 of Set 7 | Terenos
# Processing Record 48 of Set 7 | Hay River
# Processing Record 49 of Set 7 | Oodweyne
# Processing Record 50 of Set 7 | Visnes
# Processing Record 0 of Set 8 | Yaan
# Processing Record 1 of Set 8 | Grand Gaube
# Processing Record 2 of Set 8 | Rosa Zarate
# Processing Record 3 of Set 8 | Salalah
# Processing Record 4 of Set 8 | Ambon City
# Processing Record 5 of Set 8 | Virginia Beach
# Processing Record 21 of Set 9 | Guánica
# Processing Record 22 of Set 9 | Okhotsk
# Processing Record 23 of Set 9 | Gawler
# Processing Record 24 of Set 9 | Janakpur Dham
# Processing Record 25 of Set 9 | Dubbo
# Processing Record 26 of Set 9 | Barguzin
# Processing Record 27 of Set 9 | Mizque
# Processing Record 28 of Set 9 | Pachino
# Processing Record 29 of Set 9 | Nuuk
# Processing Record 30 of Set 9 | High Prairie
# Processing Record 31 of Set 9 | Duluth
# Processing Record 32 of Set 9 | Zhangye
# Processing Record 33 of Set 9 | Syracuse
# Processing Record 34 of Set 9 | Gazojak
# Processing Record 35 of Set 9 | Isla Mujeres
# Processing Record 36 of Set 9 | Takoradze
# Processing Record 37 of Set 9 | Mingshui
# Processing Record 38 of Set 9 | General Pico
# Processing Record 39 of Set 9 | Piaçabuçu
# Processing Record 40 of Set 9 | Bilibino
# Processing Record 41 of Set 9 | Lake Elsinore
# Processing Record 42 of Set 9 | Pasni
# Processing Record 43 of Set 9 | Prince George
# Processing Record 44 of Set 9 | Shubarshi
# Processing Record 45 of Set 9 | Ahipara
# Processing Record 46 of Set 9 | Wattegama
# Processing Record 47 of Set 9 | Hervey Bay
# Processing Record 48 of Set 9 | Kamenka
# City not found. Skipping...
# Processing Record 49 of Set 9 | Sīrjān
# Processing Record 50 of Set 9 | Plouzané
# Processing Record 0 of Set 10 | Ürümqi
# Processing Record 1 of Set 10 | Paita
# Processing Record 2 of Set 10 | Fare
# Processing Record 3 of Set 10 | Praia
# Processing Record 4 of Set 10 | Malakal
# Processing Record 5 of Set 10 | Adré
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 10 | Buin
# Processing Record 7 of Set 10 | Kolondiéba
# Processing Record 8 of Set 10 | Raudeberg
# Processing Record 9 of Set 10 | Mercedes
# Processing Record 10 of Set 10 | Aketi
# Processing Record 11 of Set 10 | Sibolga
# Processing Record 12 of Set 10 | Darhan
# Processing Record 13 of Set 10 | Nouakchott
# Processing Record 14 of Set 10 | Chicama
# Processing Record 15 of Set 10 | Monrovia
# Processing Record 16 of Set 10 | Emba
# Processing Record 17 of Set 10 | Kuandian
# Processing Record 18 of Set 10 | Copiapó
# Processing Record 19 of Set 10 | Opotiki
# Processing Record 20 of Set 10 | Guarapari
# Processing Record 21 of Set 10 | Mishelevka
# Processing Record 22 of Set 10 | Logansport
# City not found. Skipping...
# Processing Record 23 of Set 10 | Turlock
# Processing Record 24 of Set 10 | Port-Gentil
# Processing Record 25 of Set 10 | Tigil'
# City not found. Skipping...
# Processing Record 26 of Set 10 | Oyama
# Processing Record 27 of Set 10 | Tambovka
# Processing Record 28 of Set 10 | Nkhotakota
# Processing Record 29 of Set 10 | Teluknaga
# Processing Record 30 of Set 10 | Garden City
# Processing Record 31 of Set 10 | Asău
# City not found. Skipping...
# Processing Record 32 of Set 10 | Galle
# City not found. Skipping...
# Processing Record 33 of Set 10 | Tolaga Bay
# Processing Record 34 of Set 10 | Havøysund
# Processing Record 35 of Set 10 | Nome
# Processing Record 36 of Set 10 | Carbonia
# Processing Record 37 of Set 10 | Cayenne
# Processing Record 38 of Set 10 | Murgab
# City not found. Skipping...
# Processing Record 39 of Set 10 | Northam
# Processing Record 40 of Set 10 | Sai Buri
# Processing Record 41 of Set 10 | Poum
# City not found. Skipping...
# Processing Record 42 of Set 10 | Camopi
# Processing Record 43 of Set 10 | Malbork
# Processing Record 44 of Set 10 | São Félix do Xingu
# Processing Record 45 of Set 10 | Palmer
# Processing Record 46 of Set 10 | Coro
# Processing Record 47 of Set 10 | Srandakan
# Processing Record 48 of Set 10 | Vardø
# Processing Record 49 of Set 10 | West Wendover
# Processing Record 50 of Set 10 | Aktash
# Processing Record 0 of Set 11 | Cuamba
# Processing Record 1 of Set 11 | Malabang
# Processing Record 2 of Set 11 | Miles City
# City not found. Skipping...
# Processing Record 3 of Set 11 | Laas
# Processing Record 4 of Set 11 | Thung Song
# Processing Record 5 of Set 11 | Eufaula
# Processing Record 6 of Set 11 | Mocuba
# Processing Record 7 of Set 11 | Grindavik
# Processing Record 8 of Set 11 | Vengerovo
# Processing Record 9 of Set 11 | Görele
# Processing Record 10 of Set 11 | Petropavlivka
# Processing Record 11 of Set 11 | Tucupita
# Processing Record 12 of Set 11 | Kindia
# Processing Record 13 of Set 11 | Nanortalik
# Processing Record 14 of Set 11 | Yantongshan
# Processing Record 15 of Set 11 | Leeuwarden
# Processing Record 16 of Set 11 | Ixtapa
# Processing Record 17 of Set 11 | Abu Samrah
# Processing Record 18 of Set 11 | Adrar
# Processing Record 19 of Set 11 | Komatipoort
# Processing Record 20 of Set 11 | College
# Processing Record 21 of Set 11 | Champerico
# Processing Record 22 of Set 11 | Mastic Beach
# Processing Record 23 of Set 11 | Ambilobe
# Processing Record 24 of Set 11 | Yar-Sale
# Processing Record 25 of Set 11 | Vanimo
# City not found. Skipping...
# Processing Record 26 of Set 11 | Banda Aceh
# Processing Record 27 of Set 11 | Kuusankoski
# Processing Record 28 of Set 11 | Bud
# Processing Record 29 of Set 11 | Namtsy
# Processing Record 30 of Set 11 | Bayjī
# Processing Record 31 of Set 11 | Nemuro
# Processing Record 32 of Set 11 | Belize
# Processing Record 33 of Set 11 | San Cristobal
# Processing Record 34 of Set 11 | Huambo
# Processing Record 35 of Set 11 | Aklavik
# Processing Record 36 of Set 11 | Vârfurile
# Processing Record 37 of Set 11 | Chifeng
# Processing Record 38 of Set 11 | Hecun
# Processing Record 39 of Set 11 | Malartic
# Processing Record 40 of Set 11 | Staraya Poltavka
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Lat": latitude, "Lng": longitude, "Temp": temperature, 
                           "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": wind_speed, 
                           "Country": country, "Date": date})
weather_df.head()
# Out:
#           City      Lat       Lng   Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Albany  42.6001  -73.9662  23.67        42          96        5.10
# 1      Erenhot  43.6475  111.9767  16.38        88           0        8.48
# 2    Kavaratti  10.5669   72.6420  82.08        62           6        7.49
# 3  Broken Hill -31.9500  141.4333  66.20        26           0        8.05
# 4     Sisimiut  66.9395  -53.6735  22.05        80           0       12.33
#
#   Country        Date
# 0      US  1612807182
# 1      CN  1612807182
# 2      IN  1612807182
# 3      AU  1612807183
# 4      GL  1612807183

# %%
weather_df.to_csv("./Resources/weather_df.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.loc[weather_df['Humidity'] > 100] # There is not.
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
now = datetime.date.today()
month = now.month
day = now.day 
year = now.year


plt.figure()

plt.title(f"City Latitude vs. Temperature ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(latitude, temperature, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure()

plt.title(f"City Latitude vs. Humidity ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(latitude, humidity, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure()

plt.title(f"City Latitude vs. Cloudiness ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(latitude, cloudiness, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure()

plt.title(f"City Latitude vs. Wind Speed ({month}/{day}/{year})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(latitude, wind_speed, edgecolors="black", alpha=.75)
plt.grid(True)
plt.savefig("./Plots/Latitude_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Separate Northern and Southern Hemispheres
Northern = weather_df.loc[weather_df['Lat'] >= 0]
Southern = weather_df.loc[weather_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Temp vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(Northern['Temp'], Northern['Lat'])

correlation = st.pearsonr(Northern['Temp'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Temp'], Northern['Lat'])
regress_values = Northern['Temp'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Temp'],regress_values,"r-")
plt.annotate(line_eq,(-30,5),fontsize=15,color="red")

plt.savefig("./Plots/Temp_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is -0.87

# %% [markdown]
# ####  Southern Hemisphere - Temp vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(Southern['Temp'], Southern['Lat'])

correlation = st.pearsonr(Southern['Temp'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Temp'], Southern['Lat'])
regress_values = Southern['Temp'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Temp'],regress_values,"r-")
plt.annotate(line_eq,(70,-53),fontsize=15,color="red")

plt.savefig("./Plots/Temp_vs_Latitude_LRSouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.58

# %% [markdown]
# <blockquote>The analysis shows a strong negative correlation between temperature and latitude in the northern hemisphere and a Mild one in the southern hemisphere. This may sugest that in the northern hemisphere the temperatures are linked to the latitude but then again, correlation does not imply causation.</blockquote>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(Northern['Humidity'], Northern['Lat'])

correlation = st.pearsonr(Northern['Humidity'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Humidity'], Northern['Lat'])
regress_values = Northern['Humidity'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Humidity'],regress_values,"r-")
plt.annotate(line_eq,(7,71),fontsize=15,color="red")

plt.savefig("./Plots/Humidity_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.28

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(Southern['Humidity'], Southern['Lat'])

correlation = st.pearsonr(Southern['Humidity'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Humidity'], Southern['Lat'])
regress_values = Southern['Humidity'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Humidity'],regress_values,"r-")
plt.annotate(line_eq,(20,-5),fontsize=15,color="red")

plt.savefig("./Plots/Humidity_vs_Latitude_LR_SouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.25

# %% [markdown]
# <blockquote>The analysis shows a weak correlation between humidity and latitude in both northern and southern hemispheres. It may be that they are not related. </blockquote>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(Northern['Cloudiness'], Northern['Lat'])

correlation = st.pearsonr(Northern['Cloudiness'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Cloudiness'], Northern['Lat'])
regress_values = Northern['Cloudiness'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Cloudiness'],regress_values,"r-")
plt.annotate(line_eq,(20,75),fontsize=15,color="red")

plt.savefig("./Plots/Cloudiness_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.12

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.scatter(Southern['Cloudiness'], Southern['Lat'])

correlation = st.pearsonr(Southern['Cloudiness'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Cloudiness'], Southern['Lat'])
regress_values = Southern['Cloudiness'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Cloudiness'],regress_values,"r-")
plt.annotate(line_eq,(20,-50),fontsize=15,color="red")

plt.savefig("./Plots/Cloudiness_vs_Latitude_LR_SouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.36

# %% [markdown]
# <blockquote>The analysis shows a weak correlation between cloudiness and latitude in both northern and southern hemispheres. It may be that they are not related. </blockquote>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(Northern['Wind Speed'], Northern['Lat'])

correlation = st.pearsonr(Northern['Wind Speed'], Northern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Northern['Wind Speed'], Northern['Lat'])
regress_values = Northern['Wind Speed'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Northern['Wind Speed'],regress_values,"r-")
plt.annotate(line_eq,(25,20),fontsize=15,color="red")

plt.savefig("./Plots/WindSpeed_vs_Latitude_LR_NorthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is 0.1

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.figure()

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(Southern['Wind Speed'], Southern['Lat'])

correlation = st.pearsonr(Southern['Wind Speed'], Southern['Lat'])

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Southern['Wind Speed'], Southern['Lat'])
regress_values = Southern['Wind Speed'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(Southern['Wind Speed'],regress_values,"r-")
plt.annotate(line_eq,(15,-54),fontsize=15,color="red")

plt.savefig("./Plots/WindSpeed_vs_Latitude_LR_SouthH.png")

plt.show()

print(f"The r-value is {round(correlation[0],2)}")
# Out:
# The r-value is -0.13

# %% [markdown]
# <blockquote>The analysis shows a weak correlation between wind speed and latitude in both northern and southern hemispheres. It may be that they are not related. </blockquote>
